# %% [markdown]
# <center> <img src="img/logo_ifba.jpg" alt="jpg_python" width="100" height="200"> </center>
# <br><br>
# <div align="center"><span style="font-size: 30px;"><strong>Pré-Cálculo <br></strong></span></div> <br>
# <div align="center"><span style="font-size: 26px;"><strong>Capítulo 1: Álgebra Básica <br></strong></span></div> <br><br>

# %% [markdown]
# [🎥](https://youtu.be/Ut92VX59I_Q)

# %% [markdown]
# #
#
# <div style="margin-top: -20px;"> <hr style="border: 2px solid black;">
#
# <h1 style="text-align:center; color:black; font-size:22px;"> Aula 1: Propriedades Aritméticas Básicas </h1>
#
# <hr style="border: 2px solid black;"> </div>

# %% [markdown]
# Nesta aula, revisaremos algumas propriedades fundamentais dos números reais e a ordem das operações. Esses conhecimentos são úteis na resolução e na simplificação de expressões numéricas e algébricas, presentes em diversas áreas da Matemática e em disciplinas introdutórias de cursos das áreas de Ciências Exatas.

# %% [markdown]
# ## 1.1 Propriedades [🎥](https://youtu.be/jfY-dkn2_Lw)

# %% [markdown]
# #### <div style="color:#FF0000; font-weight:bold;">Comutatividade</div>

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;">
# Para quaisquer $a$ e $b$ reais, temos:<br>
# $$a + b = b + a \tag{1}$$<br>
# $$a \cdot b = b \cdot a \tag {2}$$
# </div>

# %% [markdown]
# #### Exemplo 1

# %% [markdown]
# A expressão $1 + 5$ pode ser calculada de duas formas:
#
# $$1 + 5 = 5 + 1 = 6$$
#
# Analogamente, a expressão $2 \cdot 3$ também pode ser calculada de duas formas:
#
# $$2 \cdot 3 = 3 \cdot 2 = 6$$

# %% [markdown]
# ##### Observação

# %% [markdown]
# Entre as quatro operações aritméticas básicas, apenas a adição e a multiplicação são comutativas. A subtração e a divisão, em geral, não são comutativas.
#
# Por exemplo, na subtração:
#
# $$
# \begin{aligned}
# 7-5 &= 2, \\
# 5-7 &= -2.
# \end{aligned}
# $$
#
# Portanto,
#
# $$
# 7-5\neq5-7.
# $$
#
# Na divisão:
#
# $$
# \begin{aligned}
# 12:3 &= 4,\\
# 3:12 &= \frac{1}{4}.
# \end{aligned}
# $$
#
# Logo,
#
# $$
# 12:3\neq3:12.
# $$

# %% [markdown]
# #### <div style="color:#FF0000; font-weight:bold;">Associatividade</div>

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;">
# Para quaisquer $a$, $b$ e $c$ reais, temos:<br>
# $$(a + b) + c = a + (b + c) \tag{3}$$<br>
# $$(a \cdot b) \cdot c = a \cdot (b \cdot c) \tag {4}$$
# </div>

# %% [markdown]
# #### Exemplo 2

# %% [markdown]
# Os termos da expressão 3+4+4 podem ser agrupados de duas formas:
#
# i) $3 + 4 + 4 = (3 + 4) + 4 = 7 + 4 = 11$
#
# ii) $3 + 4 + 4 = 3 + (4 + 4) = 3 + 8 = 11$
#
# Analogamente, a expressão $3 \cdot 2 \cdot 4$ também pode ser calculada de duas formas:
#
# i) $3 \cdot 2 \cdot 4 = (3 \cdot 2)\cdot 4 = 6 \cdot 4 = 24$
#
# ii) $3 \cdot 2 \cdot 4 = 3 \cdot (2 \cdot 4) = 3 \cdot 8 = 24$

# %% [markdown]
# ##### Observação

# %% [markdown]
# Assim como ocorre com a comutatividade, entre as quatro operações aritméticas básicas, apenas a adição e a multiplicação são associativas. A subtração e a divisão, em geral, não são associativas.
#
# Por exemplo, na subtração:
#
# $$
# \begin{aligned}
# 7 - (5 - 2) & = 7 - 3 = 4, \\
# (7 - 5) - 2 & = 2 - 2 = 0.
# \end{aligned}
# $$
#
# Portanto,
#
# $$
# 7 - (5 - 2) \neq (7 - 5) - 2.
# $$
#
# Na divisão:
#
# $$
# \begin{aligned}
# 12 : (4:2) &= 12:2 = 6,\\
# (12:4):2 &= 3:2 = \frac{3}{2}.
# \end{aligned}
# $$
#
# Logo,
#
# $$
# 12:(4:2) \neq (12:4):2.
# $$

# %% [markdown]
# #### <div style="color:#FF0000; font-weight:bold;">Distributividade</div>

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;">
# Para quaisquer $a$, $b$ e $c$ reais, temos:<br>
# $$a(b \pm c) = ab \pm ac \tag{5}$$<br>
# $$(a \pm b) c = ac \pm bc \tag {6}$$
# </div>

# %% [markdown]
# #### Exemplo 3

# %% [markdown]
# A expressão $2\cdot(3 + 1)$ pode ser calculada de duas formas:
#
# i) $2 \cdot (3 + 1) = 2 \cdot 4 = 8$
#
# ii) $2 \cdot (3 + 1) = 2\cdot 3 + 2 \cdot 1 = 6 + 2 = 8$
#
# Analogamente, a expressão $(4-3)\cdot3$ também pode ser calculada de duas formas:
#
# i) $(4-3)\cdot3 = 1 \cdot 3 = 3$
#
# ii) $(4-3)\cdot3 = 4\cdot3 - 3\cdot3 =12 - 9 = 3$

# %% [markdown]
# ## 1.2 Ordem das Operações [🎥](https://youtu.be/Ut92VX59I_Q)

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;">
# A ordem dos cálculos em expressões que envolvem múltiplas operações é a seguinte:<br>
# 1. <strong>Delimitadores:</strong> parênteses $(\ )$, colchetes $[\ ]$ e chaves $\{\ \}$.<br>
# Quando houver delimitadores aninhados, realizamos primeiro as operações contidas nos mais internos.<br>
# 2. <strong>Potenciações e radiciações:</strong> $a^n$ e $\sqrt[n]{a}$.<br>
# 3. <strong>Multiplicações e divisões:</strong> devem ser realizadas na ordem em que aparecem, da esquerda para a direita: $\cdot$ e $\div$.<br>
# 4. <strong>Adições e subtrações:</strong> devem ser realizadas na ordem em que aparecem, da esquerda para a direita: $+$ e $-$.
# </div>

# %% [markdown]
# #### Exemplo 4 [🎥](https://youtu.be/Ut92VX59I_Q&t=164s)

# %% [markdown]
# Resolva a expressão numérica:
#
# $$3\cdot(2 + 1) - 2\cdot(4-2)$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# 3\cdot(2 + 1) - 2\cdot(4-2)
# &= 3\cdot3 - 2\cdot2 \\
# &= 9 - 4 \\
# &= 5
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 5 [🎥](https://youtu.be/QrB8IOg_STU)

# %% [markdown]
# Resolva a expressão númérica:
#
# $$3\cdot2^{2} + 5 + \frac{3 + 5}{2}$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# 3\cdot2^{2} + 5 + \frac{3 + 5}{2}
# &= 3\cdot4 + 5 + \frac{8}{2} \\
# &= 12 + 5 + 4 \\
# &= 21
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 6 [🎥](https://youtu.be/CTNlAaWiURQ)

# %% [markdown]
# Resolva a expressão numérica:
#
# $$\frac{((20-8) - (6 - 2\cdot4)^{2})^{2}}{4 + 2\cdot6}$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \frac{((20-8) - (6 - 2\cdot4)^{2})^{2}}{4 + 2\cdot6}
# &= \frac{(12 - (6 - 8)^{2})^{2}}{4 + 12} \\
# &= \frac{(12 - (-2)^{2})^{2}}{16} \\
# &= \frac{(12 - 4)^{2}}{16} \\
# &= \frac{8^{2}}{16} \\
# &= \frac{64}{16} \\
# &= 4
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 7 [🎥](https://youtu.be/ae1AAXI0RaE)

# %% [markdown]
# Resolva a expressão numérica:
#
# $$\sqrt{(15-9)^{2} + \left(6\sqrt{5 + 2\cdot 2} - 2\cdot5\right)^{2}}$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \sqrt{(15-9)^{2} + \left(6\sqrt{5 + 2\cdot 2} - 2\cdot5\right)^{2}}
# &= \sqrt{6^{2} + \left(6\sqrt{5 + 4} - 10\right)^{2}}\\
# &= \sqrt{36 + \left(6\sqrt{9} - 10\right)^{2}} \\
# &= \sqrt{36 + \left(6\cdot3 - 10\right)^{2}} \\
# &= \sqrt{36 + \left(18 - 10\right)^{2}} \\
# &= \sqrt{36 + 8^{2}} \\
# &= \sqrt{36 + 64} \\
# &= \sqrt{100} \\
# &= 10
# \end{aligned}
# $$

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 1

# %% [markdown]
# Determine o valor das expressões numéricas:
#
# a) $(2 + 3\cdot2)\cdot(7 - 2^{2})^{2}$
#
# b) $\frac{(4\cdot2 + 5)^{2} - (4\cdot2 - 5)^{2}}{30 - 2\cdot(2 + 3)^{2}}$
#
# c) $\left(\sqrt{3 + (7-3)^{2}-20:2} + 1\right)^{3}$
#
# d) $\frac{\left[3\cdot(5-2)+1\right]^2-\sqrt{144}}{2^3+3}$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# (2 + 3\cdot2)\cdot(7 - 2^{2})^{2}
# &= (2 + 6)\cdot(7 - 4)^{2} \\
# &= 8\cdot3^{2} \\
# &= 8\cdot9 \\
# &= 72
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \frac{(4\cdot2 + 5)^{2} - (4\cdot2 - 5)^{2}}{30 - 2\cdot(2 + 3)^{2}}
# &= \frac{(8 + 5)^{2} - (8 - 5)^{2}}{30 - 2\cdot5^{2}} \\
# &= \frac{13^{2} - 3^{2}}{30 - 2\cdot25} \\
# &= \frac{169 - 9}{30 - 50} \\
# &= \frac{160}{-20} \\
# &= -8
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item c:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \left(\sqrt{3 + (7-3)^{2}-20:2} + 1\right)^{3}
# &= \left(\sqrt{3 + 4^{2}-10} + 1\right)^{3} \\
# &= \left(\sqrt{3 + 16 -10} + 1\right)^{3} \\
# &= \left(\sqrt{9} + 1\right)^{3} \\
# &= (3 + 1)^{3} \\
# &= 4^{3} \\
# &= 64
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item d:

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \frac{\left[3\cdot(5-2)+1\right]^2-\sqrt{144}}{2^3+3}
# &=\frac{\left[3\cdot3+1\right]^2-12}{8+3}\\
# &=\frac{(9+1)^2-12}{11}\\
# &=\frac{10^2-12}{11}\\
# &=\frac{100-12}{11}\\
# &=\frac{88}{11}\\
# &=8.
# \end{aligned}
# $$

# %% [markdown]
# #### Exercício 2

# %% [markdown]
# Um estudante resolveu a expressão numérica da seguinte maneira:
#
# $$
# \begin{aligned}
# 18\div3\cdot2+4
# &=18\div6+4\\
# &=3+4\\
# &=7.
# \end{aligned}
# $$
#
# A resolução está correta? Justifique sua resposta e, caso seja necessário, apresente a resolução correta.

# %% [markdown]
# ##### Solução:

# %% [markdown]
# A resolução está incorreta. Como a multiplicação e a divisão possuem a mesma prioridade, essas operações devem ser realizadas na ordem em que aparecem, da esquerda para a direita.
#
# Assim,
#
# $$
# \begin{aligned}
# 18\div3\cdot2+4
# &=6\cdot2+4\\
# &=12+4\\
# &=16.
# \end{aligned}
# $$
#
# Portanto, o valor correto da expressão é $16$.

# %% [markdown]
# ## Teste de Aprendizagem

# %% [markdown]
# O link a seguir leva ao **Teste de Aprendizagem da Aula 1**. Este teste é importante para avaliarmos o material desenvolvido para o curso. Contamos com a sua participação.

# %% [markdown]
# 🔗[**Teste de Aprendizagem da Aula 1**](https://forms.gle/MBhHmfmizuBFoD359)

# %% [markdown]
# #
#
# <div style="margin-top: -20px;"> <hr style="border: 2px solid black;">
#
# <h1 style="text-align:center; color:black; font-size:22px;"> Aula 2: Opreções Com Frações </h1>
#
# <hr style="border: 2px solid black;"> </div>

# %% [markdown]
# As operações com frações e quocientes são fundamentais em diversas áreas da Matemática e aparecem com frequência nos cursos de Ciências Exatas.

# %% [markdown]
# ## 2.1 Soma e Subtração

# %% [markdown]
# ### Frações com mesmo denominador

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;"> A soma ou a subtração de duas frações $\large \frac{a}{b}$ e $\large \frac{c}{b}$, com o mesmo denominador $b$ e $b \neq 0$, é dada por:<br>
#   $$\frac{a}{b} \pm \frac{c}{b} = \frac{a\pm c}{b}.$$<br>
#   Em outras palavras, mantemos o denominador e somamos ou subtraímos os numeradores.
#
# </div>

# %% [markdown]
# #### Exemplo 1

# %% [markdown]
# Determine o valor das seguintes expressões:
#
# a) $\frac{5}{6} + \frac{8}{6}$
#
# b) $\frac{23}{9} - \frac{8}{9}$
#
# c) $\frac{12}{5} + \frac{32}{10} - \frac{9}{15}$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# Como as frações possuem o mesmo denominador, mantemos o denominador e somamos os numeradores:
#
# $$
# \begin{aligned}
# \frac{5}{6}+\frac{8}{6}
# &=\frac{5+8}{6}\
# &=\frac{13}{6}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# Como as frações possuem o mesmo denominador, mantemos o denominador e subtraímos os numeradores:
#
# $$
# \begin{aligned}
# \frac{23}{9}-\frac{8}{9}
# &=\frac{23-8}{9}\
# &=\frac{15}{9}\
# &=\frac{5}{3}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item c:

# %% [markdown]
# Inicialmente, simplificamos as frações que ainda não estão escritas com denominador $5$:
#
# $$
# \frac{32}{10}=\frac{16}{5}
# \qquad\text{e}\qquad
# \frac{9}{15}=\frac{3}{5}.
# $$
#
# Assim, obtemos frações com o mesmo denominador:
#
# $$
# \begin{aligned}
# \frac{12}{5}+\frac{32}{10}-\frac{9}{15}
# &=\frac{12}{5}+\frac{16}{5}-\frac{3}{5}\\
# &=\frac{12+16-3}{5}\\
# &=\frac{25}{5}\\
# &=5.
# \end{aligned}
# $$

# %% [markdown]
# ### Frações com denominadores diferentes

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;"> Para somar ou subtrair duas frações $\large \frac{a}{b}$ e $\large \frac{c}{d}$ com denominadores diferentes, devemos primeiro encontrar um denominador comum.<br>
#     Seja<br>
#     $$M=\operatorname{mmc}(b,d),$$<br>
#     em que $\operatorname{mmc}(b,d)$ representa o mínimo múltiplo comum de $b$ e $d$. Definimos<br><br>
#     $$x=\frac{M}{b} \qquad\text{e}\qquad y=\frac{M}{d}.$$<br>
#     Assim,<br>
#     $$\frac{a}{b} \pm \frac{c}{d} = \frac{ax\pm cy}{M},$$<br>
#     com $b\neq 0$ e $d\neq 0$.
# </div>

# %% [markdown]
# #### Exemplo 2

# %% [markdown]
# Determine o valor das seguintes expressões:
#
# a) $\frac{5}{6} - \frac{7}{4}$
#
# b) $\frac{5}{2} + \frac{2}{3} - \frac{1}{4}$
#
# c) $\frac{9}{8} + \frac{1}{7} - 2$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# Determinamos inicialmente o mínimo múltiplo comum dos denominadores:
#
# $$
# \operatorname{mmc}(6,4)=12.
# $$
#
# Como
#
# $$
# \frac{12}{6}=2
# \qquad\text{e}\qquad
# \frac{12}{4}=3,
# $$
#
# temos:
#
# $$
# \begin{aligned}
# \frac{5}{6}-\frac{7}{4}
# &=\frac{5\cdot2-7\cdot3}{12}\\
# &=\frac{10-21}{12}\\
# &=-\frac{11}{12}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# Determinamos inicialmente o mínimo múltiplo comum dos denominadores:
#
# $$
# \operatorname{mmc}(2,3,4)=12.
# $$
#
# Como
#
# $$
# \frac{12}{2}=6, \ \ \frac{12}{3}=4 \ \ \text{e} \ \ \frac{12}{4}=3,
# $$
#
# temos:
#
# $$
# \begin{aligned}
# \frac{5}{2}+\frac{2}{3}-\frac{1}{4}
# &=\frac{5\cdot6+2\cdot4-1\cdot3}{12}\\
# &=\frac{30+8-3}{12}\\
# &=\frac{35}{12}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item c:

# %% [markdown]
# Podemos escrever o número inteiro $2$ na forma de uma fração:
#
# $$
# 2=\frac{2}{1}.
# $$
#
# Determinamos, então, o mínimo múltiplo comum dos denominadores:
#
# $$
# \operatorname{mmc}(8,7,1)=56.
# $$
#
# Como
#
# $$
# \frac{56}{8}=7, \ \ \frac{56}{7}=8 \ \ \text{e} \ \ \frac{56}{1}=56,
# $$
#
# temos:
#
# $$
# \begin{aligned}
# \frac{9}{8}+\frac{1}{7}-2
# &=\frac{9}{8}+\frac{1}{7}-\frac{2}{1}\\
# &=\frac{9\cdot7+1\cdot8-2\cdot56}{56}\\
# &=\frac{63+8-112}{56}\\
# &=-\frac{41}{56}.
# \end{aligned}
# $$

# %% [markdown]
# ## 2.2 Produto e Divisão

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;"> Para multiplicar duas frações, multiplicamos os numeradores entre si e os denominadores entre si.<br>
#  Assim, para $\large \frac{a}{b}$ e $\large \frac{c}{d}$, com $b\neq 0$ e $d\neq 0$, temos:<br>
#  $$\frac{a}{b}\cdot\frac{c}{d} = \frac{ac}{bd}.$$
# </div>

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f00b4b; padding:10px; border-radius:6px;"> Para dividir por uma fração, multiplicamos pela sua fração inversa.<br>
#  Assim, para $\large \frac{a}{b}$ e $\large \frac{c}{d}$, com $b\neq 0$, $c\neq 0$ e $d\neq 0$, temos:<br>
#   $$\frac{\frac{a}{b}}{\frac{c}{d}}=\frac{ad}{bc}.$$
# </div>

# %% [markdown]
# #### Exemplo 3

# %% [markdown]
# Determine o valor das seguintes expressões:
#
# a) $\frac{12}{5}\cdot\frac{28}{5}$
#
# b) $\large \frac{\frac{21}{8}}{\frac{3}{5}}$
#
# c) $\large \frac{\frac{6}{5} \cdot \frac{25}{12}}{\frac{15}{4}}$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# Multiplicamos os numeradores entre si e os denominadores entre si:
#
# $$
# \begin{aligned}
# \frac{12}{5}\cdot\frac{28}{5}
# &=\frac{12\cdot28}{5\cdot5}\\
# &=\frac{336}{25}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# Para dividir por uma fração, multiplicamos pela sua fração inversa:
#
# $$
# \begin{aligned}
# \frac{\frac{21}{8}}{\frac{3}{5}}
# &=\frac{21}{8}\cdot\frac{5}{3}\\
# &=\frac{21\cdot5}{8\cdot3}\\
# &=\frac{7\cdot5}{8}\\
# &=\frac{35}{8}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item c:

# %% [markdown]
# Para dividir por uma fração, multiplicamos pela sua fração inversa:
#
# $$
# \begin{aligned}
# \large \frac{\frac{6}{5}\cdot\frac{25}{12}}{\frac{15}{4}}
# &=\left(\frac{6}{5}\cdot\frac{25}{12}\right)\cdot\frac{4}{15}\\
# &=\frac{6\cdot25\cdot4}{5\cdot12\cdot15}\\
# &=\frac{1\cdot5\cdot1}{1\cdot2\cdot3}\\
# &=\frac{5}{6}.
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 4

# %% [markdown]
# Resolva a expressão
#
# $$\large \frac{1}{1 + \frac{1}{1 + \frac{1}{2}}}$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Iniciamos os cálculos pelas operações mais internas:
#
# $$
# \begin{aligned}
# \frac{1}{1+\frac{1}{1+\frac{1}{2}}}
# &=\frac{1}{1+\frac{1}{\frac{2+1}{2}}}\\
# &=\frac{1}{1+\frac{1}{\frac{3}{2}}}\\
# &=\frac{1}{1+\frac{2}{3}}\\
# &=\frac{1}{\frac{5}{3}}\\
# &=\frac{3}{5}.
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 5

# %% [markdown]
# Resolva a expressão
#
# $$\sqrt{2 + \frac{16}{\large \frac{3 - \frac{1}{3}}{1 - \frac{2}{3}}}}.$$

# %% [markdown]
# ##### Solução:

# %% [markdown]
# Iniciamos os cálculos pelas operações mais internas:
#
# $$
# \begin{aligned}
# \sqrt{2+\frac{16}{\large\frac{3-\frac{1}{3}}{1-\frac{2}{3}}}}
# &=
# \sqrt{2+\frac{16}{\large\frac{\frac{9-1}{3}}{\frac{3-2}{3}}}}\\
# &=
# \sqrt{2+\frac{16}{\large\frac{\frac{8}{3}}{\frac{1}{3}}}}\\[4pt]
# &=
# \sqrt{2+\frac{16}{8}}\\[4pt]
# &=
# \sqrt{2+2}\\[4pt]
# &=
# \sqrt{4}\\[4pt]
# &=2.
# \end{aligned}
# $$
#
# Portanto, o valor da expressão é $2$.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 1

# %% [markdown]
# Determine o valor das expressões:
#
# a) $1 + \frac{1}{2} + \frac{1}{3}$
#
# b) $\frac{3}{5}\cdot\frac{4}{9} - \frac{6}{5}\cdot\frac{10}{30}$
#
# c) $\large \frac{\frac{1}{3}}{\frac{3 + \frac{4}{5}}{3}}$
#
# c) $1 + \large \frac{12}{1 + \frac{6}{1+\frac{4}{1+1}}}$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# Determinamos o mínimo múltiplo comum dos denominadores:
#
# $$
# \operatorname{mmc}(1,2,3)=6.
# $$
#
# Assim,
#
# $$
# \begin{aligned}
# 1+\frac{1}{2}+\frac{1}{3}
# &=\frac{6}{6}+\frac{3}{6}+\frac{2}{6}\\[2pt]
# &=\frac{6+3+2}{6}\\
# &=\frac{11}{6}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# Realizamos inicialmente as multiplicações:
#
# $$
# \begin{aligned}
# \frac{3}{5}\cdot\frac{4}{9}
# -\frac{6}{5}\cdot\frac{10}{30}
# &=\frac{12}{45}-\frac{60}{150}\\
# &=\frac{4}{15}-\frac{2}{5}\\
# &=\frac{4}{15}-\frac{6}{15}\\
# &=-\frac{2}{15}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item c:

# %% [markdown]
# Iniciamos os cálculos pelas operações mais internas:
#
# $$
# \begin{aligned}
# \large \frac{\frac{1}{3}}{\frac{3+\frac{4}{5}}{3}}
# &= \large \frac{\frac{1}{3}}{\frac{\frac{15}{5}+\frac{4}{5}}{3}}\\
# &= \large \frac{\frac{1}{3}}{\frac{\frac{19}{5}}{3}}\\[2pt]
# &= \large \frac{\frac{1}{3}}{\frac{19}{15}}\\[2pt]
# &= \small \frac{1}{3}\cdot\frac{15}{19}\\[2pt]
# &= \small \frac{5}{19}.
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução do item d:

# %% [markdown]
# Iniciamos os cálculos pelas operações mais internas:
#
# $$
# \begin{aligned}
# 1+\frac{12}{1+\frac{6}{1+\frac{4}{1+1}}}
# &=1+\frac{12}{1+\frac{6}{1+\frac{4}{2}}}\\
# &=1+\frac{12}{1+\frac{6}{1+2}}\\
# &=1+\frac{12}{1+\frac{6}{3}}\\
# &=1+\frac{12}{1+2}\\
# &=1+\frac{12}{3}\\
# &=1+4\\
# &=5.
# \end{aligned}
# $$

# %% [markdown]
# ## Teste de Aprendizagem

# %% [markdown]
# O link a seguir leva para o **Teste de Aprendizagem da Aula 2**. Este teste é fundamental para avaliarmos o material deste curso. Contamos com a sua participação.

# %% [markdown]
# 🔗[**Teste de Aprendizagem da Aula 2**](https://forms.gle/6cbiWa44U4rysj6w9)

# %% [markdown]
# # <div style="margin-top: -20px;">
# <hr style="border: 2px solid black;">
#
# <center> <font color='black'><span style="font-size: 22px;"><strong>Aula 3: Manipulação e Simplificação de Expressões Algébricas - Parte 1</strong></span></font> <center/>
#
# <hr style="border: 2px solid black;">
# </div>

# %% [markdown]
# ## 3.1 Reescrevendo Expressões Algébricas

# %% [markdown]
# A seguir aprenderemos que existem várias formas de se escrever uma expressão algébrica.

# %% [markdown]
# #### Exemplo 1

# %% [markdown]
# Reescreva as expressões a seguir de outras formas equivalentes á primeira:
#
# a) $2(x+y)$
#
# b) $2x + 3y + 2a + 3b$

# %% [markdown]
# ##### Solução do item a:

# %% [markdown]
# A expressão $2(x+y)$ pode ser escrita nas seguintes formas:
#
# i) $2(x+y)$ = $2x + 2y$
#
# ii) $2(x+y) = 2(y+x)$
#
# iii) $2(x+y) = 2x + 2y = 2y + 2x$
#
# Podem haver mais formas!

# %% [markdown]
# ##### Solução do item b:

# %% [markdown]
# A expressão $2x + 3y + 2a + 3b$ pode ser escrita nas seguintes formas:
#
# i) $2x + 3y + 2a + 3b = 2x + 2a + 3y + 3b = 2(x + a) + 3(y + b)$
#
# ii) $2x + 3y + 2a + 3b = 3y + 3b + 2x + 2a = 3(y + b) + 2(x + a)$
#
# Podem haver mais formas!

# %% [markdown]
# ## 3.2 Simplificando Expressões Algébricas (Fator em Evidência)

# %% [markdown]
# Simplificar uma expressão significa é reduzir o número de operações presentes na mesma.

# %% [markdown]
# #### Exemplo 2

# %% [markdown]
# Simplifique a expressão a seguir:
#
# $$2(3m + x) + 5x + 2m$$

# %% [markdown]
# ##### Solução

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# 2(3m+x)+5x+2m
# &= 2\cdot 3m + 2x + 5x + 2m \\
# &= 6m + 7x + 2m \\
# &= 6m + 2m + 7x \\
# &= 8m + 7x
# \end{aligned}
# $$
#
# Note que a expressão incial possuia quatro "$\cdot$" e três "$+$", enquanto que a expressão atual possui apenas dois "$\cdot$" e uma "$+$".

# %% [markdown]
# #### Exemplo 3

# %% [markdown]
# Simplifique a expressão:
#
# $$xy + zw - xw - yz$$

# %% [markdown]
# ##### Solução

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# xy + zw - xw - yz
# &= xy - xw + zw - yz \\
# &= x(y - w) + z(w - y) \\
# &= x(y - w) - z(y - w) \\
# &= (x-z)(y - w)
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 4

# %% [markdown]
# Simplifique a expressão a seguir:
#
# $$\frac{xa + yb + xb + ya}{x^{2} + xy}$$

# %% [markdown]
# ##### Solução

# %% [markdown]
# Temos que
#
# $$
# \begin{aligned}
# \frac{xa + yb + xb + ya}{x^{2} + y}
# &= \frac{xa + ya + yb + xb}{x(x + y)} \\
# &= \frac{(x + y)a + (y + x)b}{x(x+y)} \\
# &= \frac{(x + y)a + (x + y)b}{x(x+y)} \\
# &= \frac{(x + y)(a + b)}{x(x+y)} \\
# &= \frac{a + b}{x}
# \end{aligned}
# $$

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 1

# %% [markdown]
# ## Teste de Aprendizagem

# %% [markdown]
# O link a seguir leva para o **Teste de Aprendizagem da Aula 2**. Este teste é fundamental para avaliarmos o material deste curso. Contamos com a sua participação.

# %% [markdown]
# 🔗[**Teste de Aprendizagem da Aula 3**](https://forms.gle/ZEsTYjv5nFDfqgnR7)

# %% [markdown]
# # <div style="margin-top: -20px;">
# <hr style="border: 2px solid black;">
#
# <center> <font color='black'><span style="font-size: 22px;"><strong>Aula 4: Manipulação e Simplificação de Expressões Algébricas - Parte 2</strong></span></font> <center/>
#
# <hr style="border: 2px solid black;">
# </div>

# %% [markdown]
# A manipulação e simplificação de expressões como
#
# $$\frac{x^{2}-1}{x-1} \ \ \ \ \text{e} \ \ \ \frac{(x+h)^{2} - x^{2}}{h}$$
#
# são bastante frequentes durante um curso de Cálculo.

# %% [markdown]
# ## 3.1 Fórmulas Notáveis (Grau 2)

# %% [markdown]
# O processo de simplificação e manipulação de alguma expressões algébricas requer o uso de algumas fórmulas especiais. Vejamos cada uma:

# %% [markdown]
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f77b4; padding:10px; border-radius:6px;">
#     1. $(a + b)^{2} = a^{2} + 2ab + b^{2}$<br><br>
#     2. $(a - b)^{2} = a^{2} - 2ab + b^{2}$<br><br>
#     3. $(a+b)(a-b) = a^{2} - b^{2}$
# </div>

# %% [markdown]
# #### Exemplo 5

# %% [markdown]
# Expanda cada uma das expressões a seguir:
#
# a) $(2 + 3)^{2} = $
#
# b) $(x - y)^{2} = $
#
# c) $(2x + 3y)^{2} = $
#
# d) $(3 + x)(3 - x) = $

# %% [markdown]
# ##### Solução

# %% [markdown]
# a) Usaremos a fórmula $(a + b)^{2} = a^{2} + 2ab + b^{2}$ com $a = 2$ e $b = 3$:
#
# $$
# \begin{aligned}
# (2 + 3)^{2}
# &= 2^{2} + 2\cdot2\cdot3 + 3^{2} \\
# &= 4 + 12 + 9 \\
# &= 25
# \end{aligned}
# $$
#
# b) Usaremos a fórmula $(a - b)^{2} = a^{2} -2ab + b^{2}$ com $a = x$ e $b = y$:
#
# $$
# \begin{aligned}
# (x - y)^{2}
# &= x^{2} - 2xy + y^{2}
# \end{aligned}
# $$
#
# c) Usaremos a fórmula $(a + b)^{2} = a^{2} + 2ab + b^{2}$ com $a = 2x$ e $b = 3y$:
#
# $$
# \begin{aligned}
# (2x + 3y)^{2}
# &= (2x)^{2} + 2(2x)(3y) + (3y)^{2} \\
# & = 4x^{2} + 12xy + 9y^{2}
# \end{aligned}
# $$
#
# d) Usaremos a fórmula $(a + b)(a - b) = a^{2} - b^{2}$ com $a = 3$ e $b = x$:
#
# $$
# \begin{aligned}
# (3 + x)(3 - x)
# & = 3^{2} - x^{2} \\
# & = 9 - x^{2}
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 6

# %% [markdown]
# Simplifique as expressões a seguir:
#
# a) $x^{2} + 4x + 4 = $
#
# b) $y^{2} - 16 = $
#
# c) $25 + 4x^{2} - 20x = $
#
# d) $\large \frac{x^{2} - 6x + 9}{x^{2} - 9}$ $= $

# %% [markdown]
# ##### Solução

# %% [markdown]
# a) Note que
#
# $$
# \begin{aligned}
# x^{2} + 4x + 4
# & = x^{2} + 2\cdot2x + 2^{2}\\
# & = (x + 2)^{2}.
# \end{aligned}
# $$
#
#
# b) Note que
#
# $$
# \begin{aligned}
# y^{2} - 16
# & = y^{2} - 4^{2}\\
# & = (y+4)(y-4).
# \end{aligned}
# $$
#
# c) Note que $25 + 4x^{2} - 20x$ pode ser reorganizada como $4x^{2} - 20x + 25$:
#
# Assim,
#
# $$
# \begin{aligned}
# 25 + 4x^{2} - 20x
# & = 4x^{2} - 20x + 25 \\
# & = (2x)^{2} - 2\cdot2x\cdot5 + 5^{2} \\
# & = (2x + 5)^{2}.
# \end{aligned}
# $$
#
# d) Note que
#
# i) $x^{2} - 6x + 9 = x^{2} -2\cdot3x + 3^{2} = (x - 3)^{2}$
#
# ii) $x^{2} - 9 = x^{2} - 3^{2} = (x+3)(x-3)$
#
# Portanto, podemos escrever nosso quociente da seguinte forma:
#
# $$
# \begin{aligned}
# \frac{x^{2} - 6x + 9}{x^{2} - 9}
# & = \frac{(x-3)^{2}}{(x+3)(x-3)} \\
# & = \frac{(x-3)(x-3)}{(x+3)(x-3)} \\
# & = \frac{x-3}{x+3}.
# \end{aligned}
# $$

# %% [markdown]
# ## 3.2 Caso Geral (Grau 2)

# %% [markdown]
# Note que a expressão $x^{2} - 5x + 6$ não admite fatoração em nenhuma das formas:
#
# 1. $(a + b)^{2} = a^{2} + 2ab + b^{2}$<br><br>
# 2. $(a - b)^{2} = a^{2} - 2ab + b^{2}$<br><br>
# 3. $(a+b)(a-b) = a^{2} - b^{2}$
#
# Existe uma simplicação neste caso?

# %% [markdown]
# ### Procedimento Geral

# %% [markdown]
# A resposta à questão anterior é sim. E o melhor de tudo, retira a necessidade de decorarmos as fórmulas 1, 2 e 3!
#
# O procedimento geral envolve a utilização da fórmula de Bhaskara para a fatoração de uma expressão da forma $ax^{2} + bx + c$ em que $a \neq 0$ em termos de suas raízes $x_{1}$ e $x_{2}$:
#
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f77b4; padding:10px; border-radius:6px;">
#     $$ax^{2} + bx + c = a(x-x_{1})(x-x_{2})$$<br>
#     $$x = \frac{-b \pm \sqrt{\Delta}}{2a}, \ \Delta = b^{2} - 4ac.$$
#     </div>

# %% [markdown]
# #### Observação:

# %% [markdown]
# Expressões do segundo graus incompletas $b = 0$ ou $c = 0$ podem ser resolvidas sem a aplicação da fórmula:
#
# i) $b = 0$
#
# $$
# \begin{aligned}
# x^{2} - 3x
# & = x(x-3) \\
# & = (x-0)(x-3)
# \end{aligned}
# $$
#
# Note que $x_{1} = 0 $ e $x_{2} = 3$ são as raízes de $x^{2} - 3x = 0$.
#
# ii) $c = 0$
#
# $$
# \begin{aligned}
# 2x^{2} - 18
# & \Rightarrow 2x^{2} = 18 \\
# & \Rightarrow x^{2} = \frac{18}{2} \\
# & \Rightarrow x^{2} = 9 \\
# & \Rightarrow x = \pm \sqrt{9} \\
# & \Rightarrow x_{1} = -3 \ \text{e} \ x_{2} = 3
# \end{aligned}
# $$
#
# Portanto,
#
# $$2x^{2}-18 = 2(x - (-3))(x-3) = 2(x+3)(x-3)$$

# %% [markdown]
# #### Exemplo 7

# %% [markdown]
# Simplifique as expressões a seguir:
#
# a) $x^{2} - 5x + 6 = $
#
# b) $\large \frac{x^{2} - 4x + 4}{x^{2} - 4}$ $= $

# %% [markdown]
# ##### Solução

# %% [markdown]
# a) Temos que $x^{2} -5x + 6$ é tal que
#
# $$
# \begin{aligned}
# \Delta
# & = b^{2} - 4ac \\
# & = (-5)^{2} - 4\cdot1\cdot6 \\
# & = 25 -24 \\
# & = 1
# \end{aligned}
# $$
#
# $$
# \begin{aligned}
# x
# & = \frac{-b \pm \sqrt{\Delta}}{2a} \\
# & = \frac{-(-5) \pm \sqrt{1}}{2\cdot1} \\
# & = \frac{5 \pm 1}{2} \\
# & \Rightarrow x_{1} = 2 \ \text{e} \ x_{2} = 3
# \end{aligned}
# $$
#
# Portanto,
#
# $$x^{2} - 5x + 6 = (x-2)(x-3).$$
#
# b) Temos que simplificar cada uma das parcelas do quociente $\large \frac{x^{2} - 4x + 4}{x^{2} - 4}$:
#
# i) $x^{2} - 4x + 4$
#
# $$
# \begin{aligned}
# \Delta
# & = b^{2} - 4ac \\
# & = (-4)^{2} - 4\cdot1\cdot4 \\
# & = 16-16 \\
# & = 0
# \end{aligned}
# $$
#
# $$
# \begin{aligned}
# x
# & = \frac{-b \pm \sqrt{\Delta}}{2a} \\
# & = \frac{-(-4) \pm \sqrt{0}}{2\cdot1} \\
# & = \frac{4 \pm 0}{2} \\
# & \Rightarrow x_{1} = 2 \ \text{e} \ x_{2} = 2 \\
# & \Rightarrow x^{2} - 4x + 4 = (x-2)(x-2)
# \end{aligned}
# $$
#
# ii) $x^{2} - 4$
#
# $$
# \begin{aligned}
# x^{2} - 4
# & \Rightarrow x^{2} = 4 \\
# & \Rightarrow x = \pm \sqrt{4} \\
# & \Rightarrow x_{1} = -2 \ \text{e} \ x_{2} = 2
# & \Rightarrow x^{2} - 4 = (x-2)(x+2)
# \end{aligned}
# $$
#
# Portanto,
#
# $$
# \begin{aligned}
# \frac{x^{2} - 4x + 4}{x^{2} - 4}
# & = \frac{(x-2)(x-2)}{(x-2)(x+2)} \\
# & = \frac{x-2}{x+2}
# \end{aligned}
# $$

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 1

# %% [markdown]
# ## Teste da Aula 3

# %% [markdown]
# O link a seguir leva para o **Teste da Aula 3**. Este teste é fundamental para avaliarmos o material deste curso. Contamos com a sua participação.

# %% [markdown]
# # <div style="margin-top: -20px;">
# <hr style="border: 2px solid black;">
#
# <center> <font color='black'><span style="font-size: 22px;"><strong>Aula 5: Manipulação e Simplificação de Expressões Algébricas - Parte 3</strong></span></font> <center/>
#
# <hr style="border: 2px solid black;">
# </div>

# %% [markdown]
# ## 3.3 Fórmulas Notáveis (Grau 3)

# %% [markdown]
# Algumas fórmulas de grau $3$ são especialmente importantes em disciplina como Cálculo:
#
# <div style="background-color:#eef6ff; color:#FF0000; border-left:5px solid #f77b4; padding:10px; border-radius:6px;">
#     4. $(a + b)^{3} = a^{3} + 3a^{2}b + 3ab^{2} + b^{3}$<br><br>
#     5. $(a - b)^{3} = a^{3} - 3a^{2}b + 3ab^{2} - b^{3}$<br><br>
#     6. $a^{3} + b^{3} = (a + b)(a^{2} - ab + b^{2})$<br><br>
#     7. $a^{3} - b^{3} = (a - b)(a^{2} - ab + b^{2})$
# </div>

# %% [markdown]
# #### Exemplo 8

# %% [markdown]
# Reescreva as expressões acima usando alguma das relações 4, 5, 6 ou 7 dada acima:

# %% [markdown]
# a) $(x + y)^{3}$
#
# b) $(x - 3)^{3}$
#
# c) $(x + 1)(x^{2} - x + 1)$

# %% [markdown]
# ##### Solução

# %% [markdown]
# a) Temos que a expressão $(x + y)^{3}$ tem a forma dada em 4:
#
# $$
# \begin{aligned}
# (x+y)^{3}
# & = x^{3} + 3x^{2}y + 3xy^{2} + y^{3}
# \end{aligned}
# $$
#
# b) Temos que a expressão $(x-3)^{3}$ tem a forma dada em 5:
#
# $$
# \begin{aligned}
# (x-3)^{3}
# & = x^{3} + 3x^{2}(-3) + 3x(-3)^{2} + (-3)^{3} \\
# & = x^{3} -9x^{2} + 27x - 27
# \end{aligned}
# $$
#
# c) Temos que $(x + 1)(x^{2} - x + 1)$ tem a forma dada em 6:
#
# $$
# \begin{aligned}
# (x + 1)(x^{2} - x + 1)
# & = (x + 1)(x^{2} -x\cdot1 + 1^{2}) \\
# & = x^{3} + 1^{3} \\
# & = x^{3} + 1
# \end{aligned}
# $$

# %% [markdown]
# #### Exemplo 9

# %% [markdown]
# Simplifique a expressões a seguir:
#
# a) $\large \frac{x^{3}-6x^{2} + 12x - 8}{x^{2}-4}$
#
# b) $\large \frac{x^{2} - 3x + 2}{x^{3} - 1}$

# %% [markdown]
# ##### Solução item a:

# %% [markdown]
# Devemos trabalhar com cada uma das partes do numerador e do denominador de $\large \frac{x^{3}-6x^{2} + 12x - 8}{x^{2}-6x+9}$:
#
# i) $x^{3} - 6x^{2} + 12 - 8$
#
# $$
# \begin{aligned}
# x^{3} - 6x^{2} + 12x - 8
# & = x^{3} - 3\cdot2x^{2} + 3\cdot4x - 2^{3} \\
# & = x^{3} - 3\cdot x^{2}2 + 3x\cdot2^{2} - 2^{3} \\
# & = (x-3)^{3}
# \end{aligned}
# $$
#
# ii) $x^{2} - 6x + 9$
#
# $$
# \begin{aligned}
# x^{2} - 6x + 9
# & = x^{2} - 2\cdot3x + 3^{2} \\
# & = (x-3)^{2}
# \end{aligned}
# $$
#
# Portanto,
#
# $$
# \begin{aligned}
# \frac{x^{3}-6x^{2} + 12x - 8}{x^{2}-6x+9}
# & = \frac{(x-3)^{3}}{(x-3)^{2}} \\
# & = x - 3
# \end{aligned}
# $$

# %% [markdown]
# ##### Solução item b:

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 2

# %% [markdown]
# Simplifique a expressão
#
# $$\large \frac{\frac{xz + yz^{2}}{x+y}}{\frac{x^{2}z + xyz^{2}}{x^{2}+xy}}$$

# %% [markdown]
# ##### Solução

# %% [markdown]
# Neste item usaremos a regra:
#
# <font color = 'red'> $$\large \frac{\frac{a}{b}}{\frac{c}{d}} = \small \frac{a}{b}\frac{d}{c}$$ </font>
#
# Pois bem,
#
# $$
# \begin{aligned}
# \large \frac{\frac{xz + yz^{2}}{x+y}}{\frac{x^{2}z + xyz^{2}}{x^{2}+xy}}
# &= \frac{xz + yz^{2}}{x+y}\frac{x^{2}+xy}{x^{2}z + xyz^{2}}  \\
# &= \frac{z(x + yz)}{x+y}\frac{x(x + y)}{xz(x + yz)} \\
# &= \frac{z}{x+y}\frac{x(x + y)}{xz} \\
# &= \frac{(x + y)(a + b)}{x(x+y)} \\
# &= \frac{a + b}{x}
# \end{aligned}
# $$
